# %%
# Hugginface embeddings https://python.langchain.com/docs/integrations/platforms/huggingface#embedding-models
# https://python.langchain.com/docs/integrations/text_embedding/huggingfacehub

# %% [markdown]
# Use the huggingface api to embed text into a vector.
# Compare similiarity between two embedded texts.

# %%
import os
from dotenv import load_dotenv

from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings
from langchain.evaluation import load_evaluator

# %%
def prompt_for_api_key():
    import getpass

    hf_api_key = getpass.getpass("Enter your api key")

# %%
load_dotenv()

HF_API_KEY = os.getenv("HF_API_KEY")

# %%
if not HF_API_KEY:
    prompt_for_api_key()

# %%
MODEL_NAME = "sentence-transformers/all-MiniLM-l6-v2"
embedder = HuggingFaceInferenceAPIEmbeddings(
    api_key=HF_API_KEY, model_name=MODEL_NAME
)

# %%
user_text = input("Enter some text to embed: ")
embedding = embedder.embed_query(user_text)

print(embedding)
# Out:
# [-0.006138473283499479, 0.031011775135993958, 0.06479360163211823, 0.010941474698483944, 0.0052671595476567745, -0.04747648164629936, 0.08120307326316833, 0.028980961069464684, 0.06676197797060013, 0.030300434678792953, 0.057464972138404846, -0.008623574860394001, 0.0013227601302787662, 0.0003991640987806022, -0.01884303241968155, -0.025793777778744698, -0.013042047619819641, -0.052624959498643875, -0.05829250440001488, -0.025899222120642662, -0.0333736315369606, 0.024567853659391403, -0.005226586479693651, 0.02300594188272953, 0.03286076709628105, 0.07502181828022003, 0.005801758263260126, -0.014958555810153484, -0.02875291183590889, -0.11855192482471466, -0.03932179883122444, -0.05138753354549408, 0.0766182541847229, 0.04840371012687683, -0.03025643341243267, -0.09143415838479996, 0.05118214339017868, -0.009649625979363918, -0.02151087485253811, -0.07177411764860153, -0.06322427093982697, -0.01766885630786419, 0.028081467375159264, 0.09004710614681244, 0.019417941570281982, 0.00545443594455719, 0.04830178618431091, 0.008490861393511295, 0.027750566601753235, 0.09656057506799698, 0.026302730664610863, -0.03053337335586548, -0.0688156709074974, -0.006034087855368853, -0.005675015039741993, 0.007891478016972542, -0.012150037102401257, 0.03051081672310829, 0.08959098905324936, 0.05567782744765282, 0.02408912032842636, -0.10735426098108292, -0.03346005082130432, 0.045137424021959305, 0.030472343787550926, -0.013143586926162243, -0.04747752845287323, -0.018302444368600845, -0.05733826756477356, -0.06680755317211151, 0.031541552394628525, -0.019029319286346436, 0.05133069306612015, 0.05286180600523949, 0.020830664783716202, 0.010577886365354061, 0.07542317360639572, -0.05764572694897652, -0.004973259288817644, -0.02093096636235714, -0.027561279013752937, 0.014515988528728485, -0.10756813734769821, 0.04483577609062195, 0.02291005477309227, -0.026643387973308563, -0.048390861600637436, 0.020416077226400375, -0.0673844963312149, 0.012496310286223888, -0.06567908823490143, 0.04350930079817772, 0.046210601925849915, -0.03236917033791542, -0.03542409464716911, 0.016219960525631905, 0.001181505504064262, -0.07763808220624924, -0.09475517272949219, 0.2238306850194931, 0.012382715940475464, 0.04645993933081627, 0.013210366480052471, 0.02492467127740383, 0.06359735876321793, -0.06588409096002579, -0.07702980190515518, 0.015215534716844559, 0.025661049410700798, 0.09942319244146347, 0.04657801613211632, -0.07909021526575089, -0.11972087621688843, 0.020122641697525978, 0.02802005596458912, -0.04300805553793907, -0.025948356837034225, 0.07571068406105042, 0.05857231840491295, -0.02252190001308918, -0.03293314203619957, 0.05913544073700905, -0.009753788821399212, -0.03623003140091896, -0.10333386063575745, -0.018459895625710487, -0.032019153237342834, -4.275041895832326e-33, 0.002992519410327077, -0.01928904466331005, 0.042234793305397034, -0.02313087321817875, -0.04655824601650238, -0.04273049160838127, 0.00721702678129077, 0.06616469472646713, -0.005430335644632578, 0.0361810177564621, -0.037112265825271606, -0.029162248596549034, -0.08025959879159927, -0.005587742663919926, 0.1608613133430481, -0.024541744962334633, -0.01371406577527523, 0.007908256724476814, -0.05152325704693794, 0.002702501369640231, -0.002003319328650832, -0.013435432687401772, -0.00021032027143519372, 0.029283327981829643, -0.05776261165738106, -0.05658029392361641, 0.02457783930003643, -0.06478139013051987, 0.07405763119459152, -0.0006418612319976091, -0.00014512897178065032, 0.014452973380684853, 0.013506364077329636, -0.1173020526766777, -0.04585757479071617, -0.033933334052562714, 0.007176047191023827, -0.05150112137198448, 0.06256616115570068, 0.0315965935587883, -0.0970773845911026, -0.0019338902784511447, 0.03807387873530388, 0.008525755256414413, 0.08889906108379364, 0.026826202869415283, 0.004196490161120892, 0.06285065412521362, -0.038966432213783264, 0.03450334444642067, -0.09546060115098953, -0.013940763659775257, 0.05426909402012825, 0.008143528364598751, -0. ...

# %%
evaluator = load_evaluator("embedding_distance", embeddings=embedder)

# %%
user_text_compare = input("Enter some text to compare: ")
embedding_compare = embedder.embed_query(user_text_compare)

similarity = evaluator.evaluate_strings(prediction=user_text, reference=user_text_compare)

print(f"Similarity: {similarity}")
# Out:
# Similarity: {'score': 0.6273886339419787}

# %%
string_first = "Shark"
string_second = "Fish"

similarity = evaluator.evaluate_strings(prediction=string_first, reference=string_second)
print(f"Similarity: {similarity}")
# Out:
# Similarity: {'score': 0.37752130315967614}
